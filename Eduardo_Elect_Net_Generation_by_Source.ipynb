# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from functools import reduce
import requests
import json
from pprint import pprint
from api_key import gkey

# %%
#No renewable net generation Coal
base_url = "http://api.eia.gov/series/?api_key=gkey&series_id=ELEC.GEN.COW-NM-98.A"
    #api_key=YOUR_API_KEY_HERE&series_id=SEDS.CLPRB.NM.A
parame={"api_key":gkey,"series_id":"ELEC.GEN.COW-NM-98.A"}
response_json = requests.get(base_url, params=parame).json()

response_json
pd.DataFrame(response_json["series"][0]["data"])
# Out:
#        0            1
# 0   2018  13401.53167
# 1   2017  18414.48260
# 2   2016  18365.26988
# 3   2015  20439.53176
# 4   2014  20355.63131
# 5   2013  24145.27091
# 6   2012  24994.04891
# 7   2011  27140.86343
# 8   2010  25617.78909
# 9   2009  29117.30823
# 10  2008  27014.23306
# 11  2007  27603.64738
# 12  2006  29859.00800
# 13  2005  29947.24800
# 14  2004  29263.89900
# 15  2003  28812.84400
# 16  2002  26902.88000
# 17  2001  28402.18700

# %%
NM_net_coal_production=pd.DataFrame(response_json["series"][0]["data"])
print(NM_net_coal_production)
# Out:
#        0            1
# 0   2018  13401.53167
# 1   2017  18414.48260
# 2   2016  18365.26988
# 3   2015  20439.53176
# 4   2014  20355.63131
# 5   2013  24145.27091
# 6   2012  24994.04891
# 7   2011  27140.86343
# 8   2010  25617.78909
# 9   2009  29117.30823
# 10  2008  27014.23306
# 11  2007  27603.64738
# 12  2006  29859.00800
# 13  2005  29947.24800
# 14  2004  29263.89900
# 15  2003  28812.84400
# 16  2002  26902.88000
# 17  2001  28402.18700

# %%
NM_net_coal_production.columns=["Year","Coal_Net_Generation"]
print(NM_net_coal_production)
NM_net_coal_production_sort=NM_net_coal_production.sort_values('Year',ascending=True)
NM_net_coal_production_sort
# Out:
#     Year  Coal_Net_Generation
# 0   2018          13401.53167
# 1   2017          18414.48260
# 2   2016          18365.26988
# 3   2015          20439.53176
# 4   2014          20355.63131
# 5   2013          24145.27091
# 6   2012          24994.04891
# 7   2011          27140.86343
# 8   2010          25617.78909
# 9   2009          29117.30823
# 10  2008          27014.23306
# 11  2007          27603.64738
# 12  2006          29859.00800
# 13  2005          29947.24800
# 14  2004          29263.89900
# 15  2003          28812.84400
# 16  2002          26902.88000
# 17  2001          28402.18700
#     Year  Coal_Net_Generation
# 17  2001          28402.18700
# 16  2002          26902.88000
# 15  2003          28812.84400
# 14  2004          29263.89900
# 13  2005          29947.24800
# 12  2006          29859.00800
# 11  2007          27603.64738
# 10  2008          27014.23306
# 9   2009          29117.30823
# 8   2010          25617.78909
# 7   2011          27140.86343
# ...

# %%
xb=NM_net_coal_production_sort["Year"]
yb=NM_net_coal_production_sort["Coal_Net_Generation"]

# %%
plt.plot(xb,(yb/3.412142), color = "teal", linewidth=3)

axis_font = {'fontname':'Arial', 'size':'18'}
axis_font2 = {'fontname':'Arial', 'size':'16'}

plt.title('Electricity_Net_Generation_Coal_(2001-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)
#plt.title('Energy (Electricity) Consumption by Source')
plt.grid(True)

plt.rcParams["figure.figsize"] = (14,6)
#plt.ylim(10000,32500)

# %%
base_url2="http://api.eia.gov/series/?api_key=gkey&series_id=ELEC.GEN.NG-NM-99.A"

parame={"api_key":gkey,"series_id":"ELEC.GEN.NG-NM-99.A"}
response_json = requests.get(base_url2, params=parame).json()

response_json
NM_net_gas_production=pd.DataFrame(response_json["series"][0]["data"])
NM_net_gas_production
# Out:
#        0            1
# 0   2018  11531.57010
# 1   2017   9131.65514
# 2   2016   9957.55288
# 3   2015   9364.62372
# 4   2014   8975.65614
# 5   2013   8975.24310
# 6   2012   8799.04130
# 7   2011   8565.98374
# 8   2010   8512.08263
# 9   2009   8661.07263
# 10  2008   7966.00653
# 11  2007   6660.00397
# 12  2006   5889.59888
# 13  2005   4187.21479
# 14  2004   2992.67371
# 15  2003   3518.70500
# 16  2002   3441.73900
# 17  2001   4887.27200

# %%
#No renewable net generation natural gas
NM_net_gas_production.columns=["Year","Elect_Net_Generation_Gas"]
#print(NM_net_gas_production)
NM_net_gas_production_sort=NM_net_gas_production.sort_values('Year',ascending=True)
NM_net_gas_production
# Out:
#     Year  Elect_Net_Generation_Gas
# 0   2018               11531.57010
# 1   2017                9131.65514
# 2   2016                9957.55288
# 3   2015                9364.62372
# 4   2014                8975.65614
# 5   2013                8975.24310
# 6   2012                8799.04130
# 7   2011                8565.98374
# 8   2010                8512.08263
# 9   2009                8661.07263
# 10  2008                7966.00653
# 11  2007                6660.00397
# 12  2006                5889.59888
# 13  2005                4187.21479
# 14  2004                2992.67371
# 15  2003                3518.70500
# 16  2002                3441.73900
# 17  2001                4887.27200

# %%
xa=NM_net_gas_production_sort["Year"]
ya=NM_net_gas_production_sort["Elect_Net_Generation_Gas"]

# %%
plt.plot(xa,(ya/3.412142), color = "teal", linewidth=3)

axis_font = {'fontname':'Arial', 'size':'18'}
axis_font2 = {'fontname':'Arial', 'size':'16'}

plt.title('Electricity_Net_Generation_Gas_(2001-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)
#plt.title('Energy (Electricity) Consumption by Source')
plt.grid(True)

plt.rcParams["figure.figsize"] = (14,6)
#plt.ylim(10000,32500)

# %%
# NM_net_gas_production_sort,NM_net_coal_production_sort

# %%
norenew_netproduction_data=[NM_net_coal_production_sort,NM_net_gas_production_sort]
norenew_netproduction_table=reduce (lambda left,right: pd.merge(left,right,on='Year'),norenew_netproduction_data)
norenew_netproduction_table.head()
# Out:
#    Year  Coal_Net_Generation  Elect_Net_Generation_Gas
# 0  2001            28402.187                4887.27200
# 1  2002            26902.880                3441.73900
# 2  2003            28812.844                3518.70500
# 3  2004            29263.899                2992.67371
# 4  2005            29947.248                4187.21479

# %%
norenew_netproduction_table.plot("Year",)
#plt.gca().invert_xaxis() #invert axes
axis_font = {'fontname':'Arial', 'size':'16'}
axis_font2 = {'fontname':'Arial', 'size':'14'}

plt.title('Electricity_Net_Generation_ by_Source(2001-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)

plt.grid(True)
plt.show()

# %%
base_url3="http://api.eia.gov/series/?api_key=gkey&series_id=ELEC.GEN.PEL-NM-99.A"

parame={"api_key":gkey,"series_id":"ELEC.GEN.PEL-NM-99.A"}
response_json = requests.get(base_url3, params=parame).json()

response_json
NM_net_pel_production=pd.DataFrame(response_json["series"][0]["data"])

# %%
#No renewable net generation Petrolium liquid
NM_net_pel_production.columns=["Year","Elect_Net_Generation_Pel"]
#print(NM_net_gas_production)
NM_net_pel_production_sort=NM_net_pel_production.sort_values('Year',ascending=True)
NM_net_pel_production_sort
# Out:
#     Year  Elect_Net_Generation_Pel
# 17  2001                  66.21200
# 16  2002                  33.08900
# 15  2003                  50.66900
# 14  2004                  31.37585
# 13  2005                  36.90900
# 12  2006                  41.48600
# 11  2007                  44.47054
# 10  2008                  52.58874
# 9   2009                  44.61281
# 8   2010                  49.86883
# 7   2011                  37.80071
# 6   2012                  46.14893
# 5   2013                  57.84778
# 4   2014                  63.15678
# 3   2015                  62.95843
# 2   2016                  51.68271
# 1   2017                  40.85025
# 0   2018                  20.45745

# %%
xc=NM_net_pel_production_sort["Year"]
yc=NM_net_pel_production_sort["Elect_Net_Generation_Pel"]

# %%
plt.plot(xc,(yc/3.412142), color = "teal", linewidth=3)

axis_font = {'fontname':'Arial', 'size':'18'}
axis_font2 = {'fontname':'Arial', 'size':'16'}

plt.title('Electricity_Net_Generation_ Petroleum_liquids_(2001-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)
#plt.title('Energy (Electricity) Consumption by Source')
plt.grid(True)

plt.rcParams["figure.figsize"] = (10,6)

# %%
#Renewable net generation conventional hydroelectric
base_url4="http://api.eia.gov/series/?api_key=gkey&series_id=ELEC.GEN.HYC-NM-99.A"

parame={"api_key":gkey,"series_id":"ELEC.GEN.HYC-NM-99.A"}
response_json = requests.get(base_url4, params=parame).json()

response_json
NM_net_hyc_production=pd.DataFrame(response_json["series"][0]["data"])

# %%
NM_net_hyc_production.columns=["Year","Elect_Net_Generation_Hyc"]

NM_net_hyc_production_sort=NM_net_hyc_production.sort_values('Year',ascending=True)
NM_net_hyc_production_sort
# Out:
#     Year  Elect_Net_Generation_Hyc
# 17  2001                 237.32000
# 16  2002                 264.59100
# 15  2003                 170.69900
# 14  2004                 138.94700
# 13  2005                 164.99300
# 12  2006                 198.21100
# 11  2007                 267.97800
# 10  2008                 312.28800
# 9   2009                 270.96300
# 8   2010                 217.01000
# 7   2011                 194.76600
# 6   2012                 222.81900
# 5   2013                  91.83800
# 4   2014                  98.38100
# 3   2015                  99.47300
# 2   2016                 147.97200
# 1   2017                 193.24900
# 0   2018                 192.69555

# %%
xd=NM_net_hyc_production_sort["Year"]
yd=NM_net_hyc_production_sort["Elect_Net_Generation_Hyc"]

# %%
plt.plot(xd,(yd/3.412142), color = "teal", linewidth=3)

axis_font = {'fontname':'Arial', 'size':'18'}
axis_font2 = {'fontname':'Arial', 'size':'16'}

plt.title('Electricity_Net_Generation_Conventional_Hydroelectric_(2001-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)
#plt.title('Energy (Electricity) Consumption by Source')
plt.grid(True)

plt.rcParams["figure.figsize"] = (12,6)

# %%
#Renewable net generation wind
base_url5="http://api.eia.gov/series/?api_key=gkey&series_id=ELEC.GEN.WND-NM-99.A"

parame={"api_key":gkey,"series_id":"ELEC.GEN.WND-NM-99.A"}
response_json = requests.get(base_url5, params=parame).json()

response_json
NM_net_wnd_production=pd.DataFrame(response_json["series"][0]["data"])

# %%
NM_net_wnd_production.columns=["Year","Elect_Net_Generation_Wnd"]

NM_net_wnd_production_sort=NM_net_wnd_production.sort_values('Year',ascending=True)
NM_net_wnd_production_sort
# Out:
#     Year  Elect_Net_Generation_Wnd
# 15  2003                 182.73500
# 14  2004                 513.46500
# 13  2005                 794.63000
# 12  2006                1255.43600
# 11  2007                1393.23900
# 10  2008                1642.78700
# 9   2009                1546.71800
# 8   2010                1832.18200
# 7   2011                2104.49700
# 6   2012                2225.78800
# 5   2013                2193.42100
# 4   2014                2274.75000
# 3   2015                2090.02100
# 2   2016                3605.42100
# 1   2017                4594.57108
# 0   2018                6168.26168

# %%
xe=NM_net_wnd_production_sort["Year"]
ye=NM_net_wnd_production_sort["Elect_Net_Generation_Wnd"]

# %%
plt.plot(xe,(ye/3.412142), color = "teal", linewidth=3)

axis_font = {'fontname':'Arial', 'size':'18'}
axis_font2 = {'fontname':'Arial', 'size':'16'}

plt.title('Electricity_Net_Generation_Wind_(2003-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)
#plt.title('Energy (Electricity) Consumption by Source')
plt.grid(True)

plt.rcParams["figure.figsize"] = (12,6)

# %%
#Renewable net generation, utility scale Solar
#ELEC.GEN.SUN-NM-99.A 
base_url6="http://api.eia.gov/series/?api_key=gkey&series_id=ELEC.GEN.SUN-NM-99.A"

parame={"api_key":gkey,"series_id":"ELEC.GEN.SUN-NM-99.A"}
response_json = requests.get(base_url6, params=parame).json()

response_json
NM_net_usun_production=pd.DataFrame(response_json["series"][0]["data"])

# %%
NM_net_usun_production.columns=["Year","Elect_Net_Generation_Utility_Scale_Solar"]

NM_net_usun_production_sort=NM_net_usun_production.sort_values('Year',ascending=True)
NM_net_usun_production_sort
# Out:
#    Year  Elect_Net_Generation_Utility_Scale_Solar
# 8  2010                                   8.93000
# 7  2011                                 127.80200
# 6  2012                                 333.79700
# 5  2013                                 388.04121
# 4  2014                                 515.05421
# 3  2015                                 614.87700
# 2  2016                                 751.83600
# 1  2017                                1192.64060
# 0  2018                                1291.44670

# %%
xf=NM_net_usun_production_sort["Year"]
yf=NM_net_usun_production_sort["Elect_Net_Generation_Utility_Scale_Solar"]

# %%
plt.plot(xf,(yf/3.412142), color = "teal", linewidth=3)

axis_font = {'fontname':'Arial', 'size':'18'}
axis_font2 = {'fontname':'Arial', 'size':'16'}

plt.title('Electricity_Net_Generation_Utility_Scale_Solar_(2010-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)
#plt.title('Energy (Electricity) Consumption by Source')
plt.grid(True)

plt.rcParams["figure.figsize"] = (12,6)

# %%
#Renewable net generation Geothermal
#ELEC.GEN.GEO-NM-99.A
base_url7="http://api.eia.gov/series/?api_key=gkey&series_id=ELEC.GEN.GEO-NM-99.A"

parame={"api_key":gkey,"series_id":"ELEC.GEN.GEO-NM-99.A"}
response_json = requests.get(base_url7, params=parame).json()

response_json
NM_net_geo_production=pd.DataFrame(response_json["series"][0]["data"])

# %%
NM_net_geo_production.columns=["Year","Elect_Net_Generation_Geothermal"]

NM_net_geo_production_sort=NM_net_geo_production.sort_values('Year',ascending=True)
NM_net_geo_production_sort
# Out:
#    Year  Elect_Net_Generation_Geothermal
# 5  2013                            0.069
# 4  2014                            8.736
# 3  2015                            9.675
# 2  2016                           14.218
# 1  2017                           12.963
# 0  2018                           13.138

# %%
xg=NM_net_geo_production_sort["Year"]
yg=NM_net_geo_production_sort["Elect_Net_Generation_Geothermal"]

# %%
plt.plot(xg,(yg/3.412142), color = "teal", linewidth=3)

axis_font = {'fontname':'Arial', 'size':'18'}
axis_font2 = {'fontname':'Arial', 'size':'16'}

plt.title('Electricity_Net_Generation_Geothermal_(2013-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)
#plt.title('Energy (Electricity) Consumption by Source')
plt.grid(True)

plt.rcParams["figure.figsize"] = (12,6)

# %%
#Renewable net generation other biomass
#ELEC.GEN.WAS-NM-99.A
base_url8="http://api.eia.gov/series/?api_key=gkey&series_id=ELEC.GEN.WAS-NM-99.A"

parame={"api_key":gkey,"series_id":"ELEC.GEN.WAS-NM-99.A"}
response_json = requests.get(base_url8, params=parame).json()

response_json
NM_net_biomass_production=pd.DataFrame(response_json["series"][0]["data"])

# %%
NM_net_biomass_production.columns=["Year","Elect_Net_Generation_Other_Biomass"]

NM_net_biomass_production_sort=NM_net_biomass_production.sort_values('Year',ascending=True)
NM_net_biomass_production_sort
# Out:
#     Year  Elect_Net_Generation_Other_Biomass
# 17  2001                            18.65200
# 16  2002                            19.40800
# 15  2003                             0.00000
# 14  2004                             0.00000
# 13  2005                             4.64722
# 12  2006                            21.88468
# 11  2007                            15.99393
# 10  2008                            18.88460
# 9   2009                            33.66400
# 8   2010                            13.67964
# 7   2011                             9.42642
# 6   2012                            14.26631
# 5   2013                            18.51818
# 4   2014                            14.17943
# 3   2015                            19.57339
# 2   2016                            17.81339
# 1   2017                            17.58797
# 0   2018                            20.26287

# %%
xh=NM_net_biomass_production_sort["Year"]
yh=NM_net_biomass_production_sort["Elect_Net_Generation_Other_Biomass"]

# %%
plt.plot(xh,(yh/3.412142), color = "teal", linewidth=3)

axis_font = {'fontname':'Arial', 'size':'18'}
axis_font2 = {'fontname':'Arial', 'size':'16'}

plt.title('Electricity_Net_Generation_Other_Biomass_(2001-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)
#plt.title('Energy (Electricity) Consumption by Source')
plt.grid(True)

plt.rcParams["figure.figsize"] = (12,6)

# %%
#Renewable net generation other all sources

base_url9="http://api.eia.gov/series/?api_key=gkey&series_id=ELEC.GEN.ALL-NM-99.A"

parame={"api_key":gkey,"series_id":"ELEC.GEN.ALL-NM-99.A"}
response_json = requests.get(base_url9, params=parame).json()

response_json
NM_net_All_production=pd.DataFrame(response_json["series"][0]["data"])

# %%
NM_net_All_production.columns=["Year","Elect_Net_Generation_All_Sources"]

NM_net_All_production_sort=NM_net_All_production.sort_values('Year',ascending=True)
NM_net_All_production_sort
# Out:
#     Year  Elect_Net_Generation_All_Sources
# 17  2001                       33611.64300
# 16  2002                       30661.70700
# 15  2003                       32735.65300
# 14  2004                       32940.36057
# 13  2005                       35135.64202
# 12  2006                       37265.62456
# 11  2007                       35985.33282
# 10  2008                       37009.83692
# 9   2009                       39674.33868
# 8   2010                       36251.54218
# 7   2011                       38181.13930
# 6   2012                       36635.90944
# 5   2013                       35870.96518
# 4   2014                       32306.20987
# 3   2015                       32701.39830
# 2   2016                       32912.04486
# 1   2017                       33597.41264
# 0   2018                       32639.33902

# %%
xi=NM_net_All_production_sort["Year"]
yi=NM_net_All_production_sort["Elect_Net_Generation_All_Sources"]

# %%
plt.plot(xi,(yi/3.412142), color = "teal", linewidth=3)

axis_font = {'fontname':'Arial', 'size':'18'}
axis_font2 = {'fontname':'Arial', 'size':'16'}

plt.title('Electricity_Net_Generation_All_Sources_(2001-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)
#plt.title('Energy (Electricity) Consumption by Source')
plt.grid(True)

plt.rcParams["figure.figsize"] = (18,6)

# %%
NM_net_wnd_production_sort
NM_net_usun_production_sort
NM_net_biomass_production_sort
NM_net_hyc_production_sort
renew_netproduction_data=[NM_net_wnd_production_sort,NM_net_usun_production_sort,NM_net_biomass_production_sort,NM_net_hyc_production_sort]
renew_netproduction_table=reduce (lambda left,right: pd.merge(left,right,on='Year'),renew_netproduction_data)
renew_netproduction_table
# Out:
#    Year  Elect_Net_Generation_Wnd  Elect_Net_Generation_Utility_Scale_Solar  \
# 0  2010                1832.18200                                   8.93000
# 1  2011                2104.49700                                 127.80200
# 2  2012                2225.78800                                 333.79700
# 3  2013                2193.42100                                 388.04121
# 4  2014                2274.75000                                 515.05421
# 5  2015                2090.02100                                 614.87700
# 6  2016                3605.42100                                 751.83600
# 7  2017                4594.57108                                1192.64060
# 8  2018                6168.26168                                1291.44670
#
#    Elect_Net_Generation_Other_Biomass  Elect_Net_Generation_Hyc
# 0                            13.67964                 217.01000
# 1                             9.42642                 194.76600
# ...

# %%
renew_netproduction_table.plot("Year",)
#plt.gca().invert_xaxis() #invert axes
axis_font = {'fontname':'Arial', 'size':'16'}
axis_font2 = {'fontname':'Arial', 'size':'14'}

plt.title('Electricity_Net_Generation_ by_Renewable_Sources(2010-2018)',**axis_font)
plt.xlabel("Year", **axis_font2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.ylabel('Billion-Btu', **axis_font2)

plt.grid(True)
plt.show()
