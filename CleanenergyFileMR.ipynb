# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from functools import reduce
import requests
import json
from pprint import pprint
from confy import gkey

# %%
#base_url="http://api.eia.gov/geoset/?geoset_id=sssssss&regions=NewMexico&api_key=gkey[&start=|&num=1960][&end=2016][&out=json]"

# %%
# Gathering Production data by source of enery (Btu)
#base_url="http://api.eia.gov/series/?"
#api_key=YOUR_API_KEY_HERE&series_id=SEDS.CLPRB.NM.A

#series_id_to_call=["SEDS.CLPRB.NM.A;SEDS.PAPRB.NM.A;SEDS.NGMPB.NM.A;SEDS.REPRB.NM.A"]
#parame={"api_key":gkey,"series_id":series_id_to_call}

# %%
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.CLPRB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
coal = requests.get(base_url, params=parame).json()
coal_df=pd.DataFrame(coal["series"][0]["data"])
#coal_df.rename({columns={"0": Year,"1":Energy}, inplace=True)
coal_df.columns=["Year","Coal_Energy_Production(Billion-Btu)"]
coal_df
# Out:
#     Year  Coal_Energy_Production(Billion-Btu)
# 0   2016                               246549
# 1   2015                               357525
# 2   2014                               400158
# 3   2013                               400228
# 4   2012                               409050
# 5   2011                               405952
# 6   2010                               381448
# 7   2009                               466100
# 8   2008                               475817
# 9   2007                               455522
# 10  2006                               485090
# 11  2005                               536980
# 12  2004                               510869
# 13  2003                               490629
# 14  2002                               543314
# 15  2001                               554846
# 16  2000                               513357
# 17  1999                               547678
# 18  1998                               534746
# 19  1997                               505578
# 20  1996                               452294
# 21  1995                               507955
# 22  1994                               533893
# 23  1993                               535318
# 24  1992                               457758
# 25  1991                               400542
# 26  1990                               454214
# 27  1989                               444915
# 28  1988                               407855
# 29  1987                               359625
# 30  1986                               404083
# 31  1985                               420410
# 32  1984                               397917
# 33  1983                               381364
# 34  1982                               375420
# 35  1981                               355602
# 36  1980                               345071
# 37  1979                               292444
# 38  1978                               232636
# 39  1977                               200268
# 40  1976                               175430
# 41  1975                               157541
# 42  1974                               168496
# 43  1973                               164714
# 44  1972                               154290
# 45  1971                               152924
# 46  1970                               137698
# 47  1969                                83636
# 48  1968                                64144
# 49  1967                                64780
# 50  1966                                51536
# 51  1965                                60085
# 52  1964                                55539
# 53  1963                                36384
# 54  1962                                12664
# 55  1961                                 7707
# 56  1960                                 5518

# %%
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.PAPRB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Crude = requests.get(base_url, params=parame).json()
Crude_df=pd.DataFrame(Crude["series"][0]["data"])
Crude_df.columns=["Year","Crude_Oil_Energy_Production(Billion-Btu)"]
Crude_df
# Out:
#     Year  Crude_Oil_Energy_Production(Billion-Btu)
# 0   2016                                    835561
# 1   2015                                    842640
# 2   2014                                    723347
# 3   2013                                    595289
# 4   2012                                    496178
# 5   2011                                    414503
# 6   2010                                    380300
# 7   2009                                    354832
# 8   2008                                    348899
# 9   2007                                    343238
# 10  2006                                    344822
# 11  2005                                    353585
# 12  2004                                    374199
# 13  2003                                    386216
# 14  2002                                    391860
# 15  2001                                    394406
# 16  2000                                    389748
# 17  1999                                    373381
# 18  1998                                    419502
# 19  1997                                    405037
# 20  1996                                    373978
# 21  1995                                    374146
# 22  1994                                    381907
# 23  1993                                    396848
# 24  1992                                    405838
# 25  1991                                    408419
# 26  1990                                    390050
# 27  1989                                    398541
# 28  1988                                    413163
# 29  1987                                    419502
# 30  1986                                    439130
# 31  1985                                    455474
# 32  1984                                    460149
# 33  1983                                    435980
# 34  1982                                    411939
# 35  1981                                    415094
# 36  1980                                    436879
# 37  1979                                    461964
# 38  1978                                    483517
# 39  1977                                    505893
# 40  1976                                    534354
# 41  1975                                    551365
# 42  1974                                    572431
# 43  1973                                    585719
# 44  1972                                    641045
# 45  1971                                    686790
# 46  1970                                    743467
# 47  1969                                    749517
# 48  1968                                    745590
# 49  1967                                    731635
# 50  1966                                    720093
# 51  1965                                    691163
# 52  1964                                    660405
# 53  1963                                    637658
# 54  1962                                    634102
# 55  1961                                    652807
# 56  1960                                    622804

# %%
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.NGMPB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Gas = requests.get(base_url, params=parame).json()
Gas_df=pd.DataFrame(Gas["series"][0]["data"])
Gas_df.columns=["Year","Natura_Gas_Energy_Production(Billion-Btu)"]
Gas_df
# Out:
#     Year  Natura_Gas_Energy_Production(Billion-Btu)
# 0   2016                                    1450059
# 1   2015                                    1442958
# 2   2014                                    1404289
# 3   2013                                    1338657
# 4   2012                                    1374261
# 5   2011                                    1405192
# 6   2010                                    1461316
# 7   2009                                    1557687
# 8   2008                                    1616879
# 9   2007                                    1699318
# 10  2006                                    1789427
# 11  2005                                    1837239
# 12  2004                                    1837593
# 13  2003                                    1809566
# 14  2002                                    1773084
# 15  2001                                    1822755
# 16  2000                                    1815971
# 17  1999                                    1646088
# 18  1998                                    1633893
# 19  1997                                    1749236
# 20  1996                                    1764091
# 21  1995                                    1794561
# 22  1994                                    1701891
# 23  1993                                    1596974
# 24  1992                                    1438882
# 25  1991                                    1193312
# 26  1990                                    1125997
# 27  1989                                     995155
# 28  1988                                     948646
# 29  1987                                     987050
# 30  1986                                     839140
# 31  1985                                    1063632
# 32  1984                                    1104684
# 33  1983                                    1027892
# 34  1982                                    1143884
# 35  1981                                    1306555
# 36  1980                                    1329290
# 37  1979                                    1377769
# 38  1978                                    1359415
# 39  1977                                    1388741
# 40  1976                                    1405146
# 41  1975                                    1390466
# 42  1974                                    1418349
# 43  1973                                    1397972
# 44  1972                                    1414840
# 45  1971                                    1361162
# 46  1970                                    1321757
# 47  1969                                    1320774
# 48  1968                                    1351004
# 49  1967                                    1238818
# 50  1966                                    1158242
# 51  1965                                    1087603
# 52  1964                                    1019732
# 53  1963                                     938101
# 54  1962                                     933732
# 55  1961                                     916383
# 56  1960                                     927136

# %%
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.REPRB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Renew = requests.get(base_url, params=parame).json()
Renew_df=pd.DataFrame(Renew["series"][0]["data"])
Renew_df.columns=["Year","Renewable_Energy_Production(Billion-Btu)"]
Renew_df
# Out:
#     Year  Renewable_Energy_Production(Billion-Btu)
# 0   2016                                     50045
# 1   2015                                     35709
# 2   2014                                     41959
# 3   2013                                     39772
# 4   2012                                     37798
# 5   2011                                     36040
# 6   2010                                     33169
# 7   2009                                     30999
# 8   2008                                     35347
# 9   2007                                     32736
# 10  2006                                     29371
# 11  2005                                     24068
# 12  2004                                     12326
# 13  2003                                      9554
# 14  2002                                      8690
# 15  2001                                      8027
# 16  2000                                      9202
# 17  1999                                      8965
# 18  1998                                      8466
# 19  1997                                      9025
# 20  1996                                      7587
# 21  1995                                      9073
# 22  1994                                      8601
# 23  1993                                      9667
# 24  1992                                      9255
# 25  1991                                      9139
# 26  1990                                      8336
# 27  1989                                      9275
# 28  1988                                      8485
# 29  1987                                      8882
# 30  1986                                     11713
# 31  1985                                     10998
# 32  1984                                     10332
# 33  1983                                      9739
# 34  1982                                      8425
# 35  1981                                      7850
# 36  1980                                      6223
# 37  1979                                      9922
# 38  1978                                      7989
# 39  1977                                      7328
# 40  1976                                      6781
# 41  1975                                      6002
# 42  1974                                      4919
# 43  1973                                      4896
# 44  1972                                      4746
# 45  1971                                      4965
# 46  1970                                      5548
# 47  1969                                      5682
# 48  1968                                      5706
# 49  1967                                      5678
# 50  1966                                      6210
# 51  1965                                      6075
# 52  1964                                      6300
# 53  1963                                      6469
# 54  1962                                      6791
# 55  1961                                      6937
# 56  1960                                      7373

# %%
all_data=[coal_df,Crude_df,Gas_df,Renew_df]
Production_table=reduce (lambda left,right: pd.merge(left,right,on='Year'), all_data)
Production_table.head()
# Out:
#    Year  Coal_Energy_Production(Billion-Btu)  \
# 0  2016                               246549
# 1  2015                               357525
# 2  2014                               400158
# 3  2013                               400228
# 4  2012                               409050
#
#    Crude_Oil_Energy_Production(Billion-Btu)  \
# 0                                    835561
# 1                                    842640
# 2                                    723347
# 3                                    595289
# 4                                    496178
#
#    Natura_Gas_Energy_Production(Billion-Btu)  \
# 0                                    1450059
# 1                                    1442958
# 2                                    1404289
# 3                                    1338657
# 4                                    1374261
#
#    Renewable_Energy_Production(Billion-Btu)
# 0                                     50045
# 1                                     35709
# 2                                     41959
# 3                                     39772
# 4                                     37798

# %%
Production_table.plot("Year",)
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billiion-Btu')
plt.title('Energy Production by Source')
plt.grid(True)
plt.show()

# %%
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.TETCB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Total = requests.get(base_url, params=parame).json()
Total_df=pd.DataFrame(Total["series"][0]["data"])
#coal_df.rename({columns={"0": Year,"1":Energy}, inplace=True)
Total_df.columns=["Year","Tota_Energy_Consumption(Billion-Btu)"]
Total_df.head()
# Out:
#    Year  Tota_Energy_Consumption(Billion-Btu)
# 0  2016                                667125
# 1  2015                                676563
# 2  2014                                680239
# 3  2013                                670515
# 4  2012                                666801

# %%
Total_df.plot("Year",)
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billiion-Btu')
plt.title('Total Energy Consumption')
plt.grid(True)
plt.show()

# %%
#Consumptionn by sector:
#coal...........................................................................
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.CLTCB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
coal_consump = requests.get(base_url, params=parame).json()
coal_consump_df=pd.DataFrame(coal_consump["series"][0]["data"])
#coal_df.rename({columns={"0": Year,"1":Energy}, inplace=True)
coal_consump_df.columns=["Year","Coal_Consumption(Billion-Btu)"]
#coal_consump_df.head()
#Oil..........................................................................
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.PMTCB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
oil_consump = requests.get(base_url, params=parame).json()
oil_consump_df=pd.DataFrame(oil_consump["series"][0]["data"])
#coal_df.rename({columns={"0": Year,"1":Energy}, inplace=True)
oil_consump_df.columns=["Year","Crude_oil_Consumption(Billion-Btu)"]
#oil_consump_df.head()

#Natural Gas...................................................................
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.NGTCB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
gas_consump = requests.get(base_url, params=parame).json()
gas_consump_df=pd.DataFrame(gas_consump["series"][0]["data"])
#coal_df.rename({columns={"0": Year,"1":Energy}, inplace=True)
gas_consump_df.columns=["Year","Natural_Gas_Consumption(Billion-Btu)"]
#gas_consump_df.head()

# %%
#Renewable_Energy..................................................................
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.RETCB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
renew_consump = requests.get(base_url, params=parame).json()
renew_consump_df=pd.DataFrame(renew_consump["series"][0]["data"])
renew_consump_df.columns=["Year","Renewable_Energys_Consumption(Billion-Btu)"]
#renew_consump_df.head()

# %%
all_Comsupmtion_data=[coal_consump_df,oil_consump_df,gas_consump_df,renew_consump_df]
Consumption_table=reduce(lambda left,right: pd.merge(left,right,on='Year'), all_Comsupmtion_data)
Consumption_table.head()
# Out:
#    Year  Coal_Consumption(Billion-Btu)  Crude_oil_Consumption(Billion-Btu)  \
# 0  2016                         197083                              237867
# 1  2015                         215703                              239184
# 2  2014                         215348                              241242
# 3  2013                         256377                              232753
# 4  2012                         263439                              232630
#
#    Natural_Gas_Consumption(Billion-Btu)  \
# 0                                259158
# 1                                260038
# 2                                256056
# 3                                252867
# 4                                249815
#
#    Renewable_Energys_Consumption(Billion-Btu)
# 0                                       58296
# 1                                       44125
# 2                                       46598
# 3                                       44906
# 4                                       43728

# %%
Consumption_table.plot("Year",)
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billiion-Btu')
plt.title('Energy Consumption by Source')
plt.grid(True)
plt.show()

# %%
#Total Consumption per capita..................................................................
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.TETPB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Total_perCapita_consump = requests.get(base_url, params=parame).json()
Total_perCapita_consump_df=pd.DataFrame(Total_perCapita_consump["series"][0]["data"])
Total_perCapita_consump_df.columns=["Year","Total(per Capita)_Consumption(Billion-Btu)"]
Total_perCapita_consump_df.head()
# Out:
#    Year  Total(per Capita)_Consumption(Billion-Btu)
# 0  2016                                       319.9
# 1  2015                                       324.9
# 2  2014                                       326.5
# 3  2013                                       321.6
# 4  2012                                       320.0

# %%
Total_perCapita_consump_df.plot("Year",)
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billiion-Btu')
plt.title('Energy Consumption Per-Capita')
plt.grid(True)
plt.show()

# %%
#drilling down to Electricity  Renewables Net Generation Electric power (total)...............................................................
base_url="http://api.eia.gov/series/?"
series_id_to_call=["ELEC.GEN.AOR-NM-98.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Renewables_Net_Generation = requests.get(base_url, params=parame).json()
Renewables_Net_Generation_df=pd.DataFrame(Renewables_Net_Generation["series"][0]["data"])
Renewables_Net_Generation_df.columns=["Year","Renewables Net Generation(Thousand Megawatthours)"]
Unit_Cal=Renewables_Net_Generation_df["Renewables Net Generation(Thousand Megawatthours)"]*(3.412)
Renewables_Net_Generation_df["Renewables Net Generation(Billion-Btu)"]=Unit_Cal
Renewables_Net_Generation_df=Renewables_Net_Generation_df.drop("Renewables Net Generation(Thousand Megawatthours)",axis=1)
Renewables_Net_Generation_df.head()
# Out:
#    Year  Renewables Net Generation(Billion-Btu)
# 0  2018                            25556.523333
# 1  2017                            19840.785630
# 2  2016                            14966.793923
# 3  2015                             9319.227639
# 4  2014                             9586.398328

# %%
Renewables_Net_Generation_df.plot("Year",)
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billion-Btu')
plt.title('Energy(Electricity) Generation From Renewable')
plt.grid(True)
plt.show()

# %%
#Solar Net_Generation
base_url="http://api.eia.gov/series/?"
series_id_to_call=["ELEC.GEN.SUN-NM-98.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Solar_Net_Generation = requests.get(base_url, params=parame).json()
Solar_Net_Generation_df=pd.DataFrame(Solar_Net_Generation["series"][0]["data"])
Solar_Net_Generation_df.columns=["Year","Solar Net Generation(Thousand Megawatthours)"]
Solar_Net_Generation_df.columns=["Year","Solar Net Generation(Thousand Megawatthours)"]
Unit_Cal=Solar_Net_Generation_df["Solar Net Generation(Thousand Megawatthours)"]*(3.412)
Solar_Net_Generation_df["Solar Net Generation(Billion-Btu)"]=Unit_Cal
Solar_Net_Generation_df=Solar_Net_Generation_df.drop("Solar Net Generation(Thousand Megawatthours)",axis=1)
Solar_Net_Generation_df.head()
# Out:
#    Year  Solar Net Generation(Billion-Btu)
# 0  2018                        4406.416140
# 1  2017                        4069.289727
# 2  2016                        2565.264432
# 3  2015                        2097.960324
# 4  2014                        1757.364965

# %%
Solar_Net_Generation_df.plot("Year",)
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billion-Btu')
plt.title('Energy(Electricity) Generation From Solar')
plt.grid(True)
plt.show()

# %%
# Coal Consumption to generate Electicity

base_url="http://api.eia.gov/series/?"
series_id_to_call=["ELEC.CONS_TOT_BTU.COW-NM-98.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Coal_Electicity_Consu = requests.get(base_url, params=parame).json()
Coal_Electicity_Consu_df=pd.DataFrame(Coal_Electicity_Consu ["series"][0]["data"])
Coal_Electicity_Consu_df.columns=["Year","Coal Electicity Consumption(Billion-Btu?)"]
New_Col=Coal_Electicity_Consu_df["Coal Electicity Consumption(Billion-Btu?)"]*1000
#Coal_Electicity_Consu_df.head() # We have to change the unit 
Coal_Electicity_Consu_df["Coal Electicity Consumption(Billion-Btu)"]=New_Col
Coal_Electicity_Consu_df = Coal_Electicity_Consu_df.drop("Coal Electicity Consumption(Billion-Btu?)",axis=1)
Coal_Electicity_Consu_df.head()
# Out:
#    Year  Coal Electicity Consumption(Billion-Btu)
# 0  2018                                 135031.06
# 1  2017                                 197336.77
# 2  2016                                 195274.57
# 3  2015                                 214012.66
# 4  2014                                 213897.67

# %%
# Petroleum liquids Consumption to generate Electicity

base_url="http://api.eia.gov/series/?"
series_id_to_call=["ELEC.CONS_TOT_BTU.PEL-NM-98.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Petroleum_Electicity_Consu = requests.get(base_url, params=parame).json()
Petroleum_Electicity_Consu_df=pd.DataFrame(Petroleum_Electicity_Consu["series"][0]["data"])
Petroleum_Electicity_Consu_df.columns=["Year","Petroleum liquids Electicity Consumption(Billion-Btu?)"]
Unit_Cal=Petroleum_Electicity_Consu_df["Petroleum liquids Electicity Consumption(Billion-Btu?)"]*1000 
Petroleum_Electicity_Consu_df["Petroleum liquids Electicity Consumption(Billion-Btu)"]=Unit_Cal
Petroleum_Electicity_Consu_df=Petroleum_Electicity_Consu_df.drop("Petroleum liquids Electicity Consumption(Billion-Btu?)",axis=1)
Petroleum_Electicity_Consu_df.head() # We have to change the unit
# Out:
#    Year  Petroleum liquids Electicity Consumption(Billion-Btu)
# 0  2018                                             234.19
# 1  2017                                             455.74
# 2  2016                                             569.31
# 3  2015                                             713.56
# 4  2014                                             698.28

# %%
# Natural Gas Consumption to generate Electicity

base_url="http://api.eia.gov/series/?"
series_id_to_call=["ELEC.CONS_TOT_BTU.NG-NM-98.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Natural_Gas_Consu = requests.get(base_url, params=parame).json()
Natural_Gas_Consu_df=pd.DataFrame(Natural_Gas_Consu["series"][0]["data"])
Natural_Gas_Consu_df.columns=["Year","Natural_Gas_Electicity Consumption(Billion-Btu?)"]
Unit_Cal=Natural_Gas_Consu_df["Natural_Gas_Electicity Consumption(Billion-Btu?)"]*1000 
Natural_Gas_Consu_df["Natural Gas Electicity Consumption(Billion-Btu)"]=Unit_Cal
Natural_Gas_Consu_df=Natural_Gas_Consu_df.drop("Natural_Gas_Electicity Consumption(Billion-Btu?)",axis=1)
Natural_Gas_Consu_df.head() # We have to change the unit
# Out:
#    Year  Natural Gas Electicity Consumption(Billion-Btu)
# 0  2018                                        100146.56
# 1  2017                                         78800.44
# 2  2016                                         85374.03
# 3  2015                                         81243.94
# 4  2014                                         79539.85

# %%
all_Comsupmtion_Electricity_data=[Coal_Electicity_Consu_df,Petroleum_Electicity_Consu_df,Natural_Gas_Consu_df]
Electricity_Consumption_table=reduce(lambda left,right: pd.merge(left,right,on='Year'), all_Comsupmtion_Electricity_data)
Electricity_Consumption_table.head()
# Out:
#    Year  Coal Electicity Consumption(Billion-Btu)  \
# 0  2018                                 135031.06
# 1  2017                                 197336.77
# 2  2016                                 195274.57
# 3  2015                                 214012.66
# 4  2014                                 213897.67
#
#    Petroleum liquids Electicity Consumption(Billion-Btu)  \
# 0                                             234.19
# 1                                             455.74
# 2                                             569.31
# 3                                             713.56
# 4                                             698.28
#
#    Natural Gas Electicity Consumption(Billion-Btu)
# 0                                        100146.56
# 1                                         78800.44
# 2                                         85374.03
# 3                                         81243.94
# 4                                         79539.85

# %%
Electricity_Consumption_table.plot("Year",)
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billion-Btu')
plt.title('Energy (Electricity) Consumption by Source')
plt.grid(True)
plt.show()

# %%
#EIA Data Sets > Electricity > Net generation > By fuel type > Wind > Electric power (total)
base_url="http://api.eia.gov/series/?"
series_id_to_call=["ELEC.GEN.WND-NM-98.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Wind_Net_Gen = requests.get(base_url, params=parame).json()
Wind_Net_Gen_df=pd.DataFrame(Wind_Net_Gen["series"][0]["data"])
Wind_Net_Gen_df.columns=["Year","Wind Net Generation(Thousand Megawatthours)"]
Unit_Cal=Wind_Net_Gen_df["Wind Net Generation(Thousand Megawatthours)"]*(3.412)
Wind_Net_Gen_df["Wind Net Generation(Billion-Btu)"]=Unit_Cal
Wind_Net_Gen_df=Wind_Net_Gen_df.drop("Wind Net Generation(Thousand Megawatthours)",axis=1)
Wind_Net_Gen_df
# Out:
#     Year  Wind Net Generation(Billion-Btu)
# 0   2018                      21036.143424
# 1   2017                      15667.255993
# 2   2016                      12292.238388
# 3   2015                       7121.471808
# 4   2014                       7750.845916
# 5   2013                       7473.235360
# 6   2012                       7582.286292
# 7   2011                       7168.867900
# 8   2010                       6251.404984
# 9   2009                       5277.401816
# 10  2008                       5605.189244
# 11  2007                       4753.731468
# 12  2006                       4283.547632
# 13  2005                       2711.277560
# 14  2004                       1751.942580
# 15  2003                        623.491820

# %%
Wind_Net_Gen_df.plot("Year", "Wind Net Generation(Billion-Btu)")
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billion-Btu')
plt.xlabel('Year')
plt.title('Wind Net Generation')
plt.grid(True)
#plt.axis([Year, Wind Net Generation(Billion-Btu)])
plt.show()

# %%
#EIA Data Sets > State Energy Data System (SEDS) > Prices & Expenditures > Prices > All Sectors (Average) > Electricity Imports
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.ELIMD.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Eimports = requests.get(base_url, params=parame).json()
Imports_df=pd.DataFrame(Eimports["series"][0]["data"])
Imports_df.columns=["Year","Electricity Imports Average Price(Dollars per million Btu)"]
#Unit_Cal=Imports_df["Wind Net Generation(Thousand Megawatthours)"]*(3.412)
#Imports_df["Wind Net Generation(Billion-Btu)"]=Unit_Cal
#Wind_Net_Gen_df=Wind_Net_Gen_df.drop("Wind Net Generation(Thousand Megawatthours)",axis=1)
Imports_df
# Out:
#     Year  Electricity Imports Average Price(Dollars per million Btu)
# 0   2017                                               9.18
# 1   2016                                               8.74
# 2   2015                                              10.54
# 3   2014                                              13.31
# 4   2013                                              11.49
# 5   2012                                               9.51
# 6   2011                                              11.53
# 7   2010                                              13.31
# 8   2009                                              12.10
# 9   2008                                              18.28
# 10  2007                                              18.25
# 11  2006                                              17.32
# 12  2005                                              16.53
# 13  2004                                              13.84
# 14  2003                                              13.21
# 15  2002                                               8.94
# 16  2001                                               0.00
# 17  2000                                              16.78
# 18  1999                                               0.00
# 19  1998                                               0.00
# 20  1997                                               0.00
# 21  1996                                               0.00
# 22  1995                                               0.00
# 23  1994                                               0.00
# 24  1993                                               0.00
# 25  1992                                               0.00
# 26  1991                                               0.00
# 27  1990                                               0.00
# 28  1989                                               0.00
# 29  1988                                               0.00
# 30  1987                                               0.00
# 31  1986                                               0.00
# 32  1985                                               0.00
# 33  1984                                               0.00
# 34  1983                                               0.00
# 35  1982                                               0.00
# 36  1981                                               0.00
# 37  1980                                               0.00
# 38  1979                                               0.00
# 39  1978                                               0.00
# 40  1977                                               0.00
# 41  1976                                               0.00
# 42  1975                                               0.00
# 43  1974                                               0.00
# 44  1973                                               0.00
# 45  1972                                               0.00
# 46  1971                                               0.00
# 47  1970                                               0.00

# %%
Imports_df.plot("Year", "Electricity Imports Average Price(Dollars per million Btu)")
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Dollars per million-Btu')
plt.xlabel('Year')
plt.title('Average Price')
plt.grid(True)
#plt.axis([Year, Wind Net Generation(Billion-Btu)])
plt.show()

# %%
#EIA Data Sets > State Energy Data System (SEDS) > Consumption > Total All Sectors > Solar Energy > Btu
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.SOTCB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Solar_Consumption = requests.get(base_url, params=parame).json()
SC_df=pd.DataFrame(Solar_Consumption["series"][0]["data"])
SC_df.columns=["Year","Solar Energy Total Consumption(Billion-Btu)"]
#Unit_Cal=Imports_df["Wind Net Generation(Thousand Megawatthours)"]*(3.412)
#Imports_df["Wind Net Generation(Billion-Btu)"]=Unit_Cal
#Wind_Net_Gen_df=Wind_Net_Gen_df.drop("Wind Net Generation(Thousand Megawatthours)",axis=1)
SC_df.head()
# Out:
#    Year  Solar Energy Total Consumption(Billion-Btu)
# 0  2016                                         8586
# 1  2015                                         7254
# 2  2014                                         6233
# 3  2013                                         4715
# 4  2012                                         3853

# %%
SC_df.plot("Year", "Solar Energy Total Consumption(Billion-Btu)")
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billion-Btu')
plt.xlabel('Year')
plt.title('Solar Energy Total Consumption')
plt.grid(True)
#plt.axis([Year, Wind Net Generation(Billion-Btu)])
plt.show()

# %%
#EIA Data Sets > State Energy Data System (SEDS) > Consumption > Total All Sectors > Wind Energy > Btu
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.WYTCB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Wind_Consumption = requests.get(base_url, params=parame).json()
WC_df=pd.DataFrame(Wind_Consumption["series"][0]["data"])
WC_df.columns=["Year","Wind Energy Total Consumption(Billion-Btu)"]
#Unit_Cal=Imports_df["Wind Net Generation(Thousand Megawatthours)"]*(3.412)
#Imports_df["Wind Net Generation(Billion-Btu)"]=Unit_Cal
#Wind_Net_Gen_df=Wind_Net_Gen_df.drop("Wind Net Generation(Thousand Megawatthours)",axis=1)
WC_df.head()
# Out:
#    Year  Wind Energy Total Consumption(Billion-Btu)
# 0  2016                                       33285
# 1  2015                                       19477
# 2  2014                                       21633
# 3  2013                                       20927
# 4  2012                                       21181

# %%
WC_df.plot("Year", "Wind Energy Total Consumption(Billion-Btu)")
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billion-Btu')
plt.xlabel('Year')
plt.title('Wind Energy Total Consumption')
plt.grid(True)
#plt.axis([Year, Wind Net Generation(Billion-Btu)])
plt.show()

# %%
#EIA Data Sets > State Energy Data System (SEDS) > Consumption > Total All Sectors > Hydroelectricity > Btu
base_url="http://api.eia.gov/series/?"
series_id_to_call=["SEDS.HYTCB.NM.A"]
parame={"api_key":gkey,"series_id":series_id_to_call}
Hydro_Consumption = requests.get(base_url, params=parame).json()
HP_df=pd.DataFrame(Hydro_Consumption["series"][0]["data"])
HP_df.columns=["Year","Hydropower Total Consumption(Billion-Btu)"]
#Unit_Cal=Imports_df["Wind Net Generation(Thousand Megawatthours)"]*(3.412)
#Imports_df["Wind Net Generation(Billion-Btu)"]=Unit_Cal
#Wind_Net_Gen_df=Wind_Net_Gen_df.drop("Wind Net Generation(Thousand Megawatthours)",axis=1)
HP_df.head()
# Out:
#    Year  Hydropower Total Consumption(Billion-Btu)
# 0  2016                                       1366
# 1  2015                                        927
# 2  2014                                        936
# 3  2013                                        876
# 4  2012                                       2120

# %%
HP_df.plot("Year", "Hydropower Total Consumption(Billion-Btu)")
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billion-Btu')
plt.xlabel('Year')
plt.title('Hydropower Total Consumption')
plt.grid(True)
#plt.axis([Year, Wind Net Generation(Billion-Btu)])
plt.show()

# %%
RenewableConsumption_data=[WC_df,SC_df,HP_df]
ReNewConsumption_table=reduce (lambda left,right: pd.merge(left,right,on='Year'), RenewableConsumption_data)
ReNewConsumption_table.head()
# Out:
#    Year  Wind Energy Total Consumption(Billion-Btu)  \
# 0  2016                                       33285
# 1  2015                                       19477
# 2  2014                                       21633
# 3  2013                                       20927
# 4  2012                                       21181
#
#    Solar Energy Total Consumption(Billion-Btu)  \
# 0                                         8586
# 1                                         7254
# 2                                         6233
# 3                                         4715
# 4                                         3853
#
#    Hydropower Total Consumption(Billion-Btu)
# 0                                       1366
# 1                                        927
# 2                                        936
# 3                                        876
# 4                                       2120

# %%
ReNewConsumption_table.plot("Year",)
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billion-Btu')
plt.title('Renewable Energy Consumption by Source')
plt.grid(True)
plt.show()

# %%
All_Consumption_data=[Coal_Electicity_Consu_df,Petroleum_Electicity_Consu_df,Natural_Gas_Consu_df,WC_df,SC_df,HP_df]
Total_Consumption_table=reduce(lambda left,right: pd.merge(left,right,on='Year'), All_Consumption_data)
Total_Consumption_table.head()
# Out:
#    Year  Coal Electicity Consumption(Billion-Btu)  \
# 0  2016                                 195274.57
# 1  2015                                 214012.66
# 2  2014                                 213897.67
# 3  2013                                 255137.09
# 4  2012                                 262424.25
#
#    Petroleum liquids Electicity Consumption(Billion-Btu)  \
# 0                                             569.31
# 1                                             713.56
# 2                                             698.28
# 3                                             624.59
# 4                                             495.62
#
#    Natural Gas Electicity Consumption(Billion-Btu)  \
# 0                                         85374.03
# 1                                         81243.94
# 2                                         79539.85
# 3                                         76977.84
# 4                                         76395.71
#
#    Wind Energy Total Consumption(Billion-Btu)  \
# 0                                       33285
# 1                                       19477
# 2                                       21633
# 3                                       20927
# 4                                       21181
#
#    Solar Energy Total Consumption(Billion-Btu)  \
# 0                                         8586
# 1                                         7254
# 2                                         6233
# 3                                         4715
# 4                                         3853
#
#    Hydropower Total Consumption(Billion-Btu)
# 0                                       1366
# 1                                        927
# 2                                        936
# 3                                        876
# 4                                       2120

# %%
Total_Consumption_table.plot("Year",)
plt.gca().invert_xaxis() #invert axes
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Billion-Btu')
plt.title('Total Consumption by Source')
plt.grid(True)
plt.show()

# %%
sources = ["Wind", "Solar", "Natural Gas", "Coal"]
perc_gen = [14, 5, 27, 54]
colors = ["orange", "yellow", "yellowgreen", "grey"]
explode = (0, 0, 0, 0.05)
#source: 350newmexico.org for the %s

# %%
plt.title("Current Electricity Generation")
plt.pie(perc_gen, explode=explode, labels=sources, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis("equal")
plt.show()
