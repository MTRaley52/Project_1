# %%
import pandas as pd
import numpy as np
import json
import requests
from confy import gkey
import matplotlib.pyplot as plt

# %%
#base URL: http://api.eia.gov/category/?api_key=YOUR_API_KEY_HERE&category_id=371
url = "http://api.eia.gov/category/?"


#EIA Data Sets > Electricity > Net generation > By fuel type > All solar > New Mexico
parame={"api_key":gkey, "category_id":"ELEC.GEN.TSN-NM-99.A"}


#generating data via the url and api key
response_json = requests.get(url, params=parame).json()
response_json
print(json.dumps(response_json, indent=4, sort_keys=True))
#response_json ["category"]["name"]
# Out:
# {
#     "category": {
#         "category_id": "0",
#         "childcategories": [
#             {
#                 "category_id": 1,
#                 "name": "Net generation"
#             },
#             {
#                 "category_id": 32,
#                 "name": "Total consumption (Btu)"
#             },
#             {
#                 "category_id": 33,
#                 "name": "Consumption for electricity generation (Btu)"
#             },
#             {
#                 "category_id": 34,
#                 "name": "Consumption for useful thermal output (Btu)"
#             },
#             {
#                 "category_id": 35,
#                 "name": "Total consumption"
#             },
#             {
#                 "category_id": 36,
#                 "name": "Consumption for electricity generation"
#             },
#             {
#                 "category_id": 37,
#                 "name": "Consumption for useful thermal output"
#             },
#             {
#                 "category_id": 38,
#                 "name": "Retail sales of electricity"
#             },
#             {
#                 "category_id": 39,
#                 "name": "Revenue from retail sales of electricity"
#             },
#             {
#                 "category_id": 40,
#                 "name": "Average retail price of electricity"
#             },
#             {
#                 "category_id": 1017,
#                 "name": "Plant level data"
#             },
#             {
#                 "category_id": 41137,
#                 "name": "Fossil-fuel stocks for electricity generation"
#             },
#             {
#                 "category_id": 41138,
#                 "name": "Receipts of fossil fuels by electricity plants"
#             },
#             {
#                 "category_id": 41139,
#                 "name": "Receipts of fossil fuels by electricity plants (Btu)"
#             },
#             {
#                 "category_id": 41140,
#                 "name": "Average cost of fossil fuels for electricity generation"
#             },
#             {
#                 "category_id": 41141,
#                 "name": "Average cost of fossil fuels for electricity generation (per Btu)"
#             },
#             {
#                 "category_id": 41142,
#                 "name": "Quality of fossil fuels in electricity generation : sulfur content"
#             },
#             {
#                 "category_id": 41143,
#                 "name": "Quality of fossil fuels in electricity generation : ash content"
#             },
#             {
#                 "category_id": 1718389,
#                 "name": "Number of customer accounts"
#             }
#         ],
#         "childseries": [],
#         "name": "Electricity",
#         "notes": "",
#         "parent_category_id": "371"
#     },
#     "request": {
#         "category_id": 0,
#         "command": "category"
#     }
# }
